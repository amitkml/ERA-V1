# %%
import  model
import util
import torch.optim as optim

# %%
## creating the network instance and finding out the parameters
myetwork = model.Network()
myetwork.show_parameters_layer()
optimizer = optim.Adam(myetwork.parameters(), lr=0.01)
# Out:
# conv1.weight 		 torch.Size([6, 1, 5, 5])
# conv1.bias 		 torch.Size([6])
# conv2.weight 		 torch.Size([12, 6, 5, 5])
# conv2.bias 		 torch.Size([12])
# fc1.weight 		 torch.Size([120, 192])
# fc1.bias 		 torch.Size([120])
# fc2.weight 		 torch.Size([60, 120])
# fc2.bias 		 torch.Size([60])
# out.weight 		 torch.Size([10, 60])
# out.bias 		 torch.Size([10])

# %%
## following code will create a train dataloader and thhen display the images
train_loaderx = util.prepare_data_loader()
util.show_images_batch_from_loader(train_loaderx)
# Out:
# labels: tensor([8, 6, 7, 0, 3, 7, 7, 1, 6, 1, 3, 3, 1, 0, 2, 4, 9, 2, 1, 1, 2, 6, 4, 8, 5, 3, 4, 8, 0, 5, 7, 9])

# %%
util.train_model(myetwork, optimizer, epochs=10)
# Out:
# epoch: 0 total_correct: 46531 loss: 1118.2852777391672
# epoch: 1 total_correct: 49323 loss: 893.7786799743772
# epoch: 2 total_correct: 49935 loss: 850.5241310223937
# epoch: 3 total_correct: 50209 loss: 825.6665097028017
# epoch: 4 total_correct: 50375 loss: 813.9653303548694
# epoch: 5 total_correct: 50609 loss: 792.740708746016
# epoch: 6 total_correct: 50956 loss: 769.4365234002471
# epoch: 7 total_correct: 50915 loss: 774.8178081065416
# epoch: 8 total_correct: 50570 loss: 800.0121764391661
# epoch: 9 total_correct: 51087 loss: 764.4462266564369
